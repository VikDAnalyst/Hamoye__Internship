# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
food_data=pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv',
                      encoding='latin-1')

# %%
my_tuppy=(1,2,5,8)

# %%
my_tuppy[2]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-cff72deb84ab> in <cell line: 1>()
# ----> 1 my_tuppy[2]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
food_data.groupby(['Element', 'Area']).sum()
# Out:
# <ipython-input-102-25fe946d25aa>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby(['Element', 'Area']).sum()
#                                                 Area Code  Item Code  \
# Element                  Area
# Domestic supply quantity Algeria                      464     311204
#                          Angola                       826     316106
#                          Benin                       6148     310985
#                          Botswana                    2340     313766
#                          Burkina Faso               27494     316106
# ...                                                   ...        ...
# Tourist consumption      Cabo Verde                  3150     241236
#                          Egypt                       5546     251428
# ...

# %%
miss=food_data.isnull().sum()
percentage_miss = (miss/ len(food_data)) * 100
print(miss)
percentage_miss
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64
# Area Code       0.000000
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y2014           2.607354
# Y2015           2.540078
# Y2016           2.518747
# Y2017           2.471162
# Y2018           2.356300
# dtype: float64

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]
x=y[1][1]
x
# Out:
# 8

# %%
food_data.shape
# Out:
# (60943, 12)

# %%
a=food_data.describe()
round(a,2)
# Out:
#        Area Code  Item Code  Element Code      Y2014      Y2015      Y2016  \
# count   60943.00   60943.00      60943.00   59354.00   59395.00   59408.00
# mean      134.27    2687.18       3814.86     134.20     135.24     136.56
# std        72.61     146.06       2212.01    1567.66    1603.40    1640.01
# min         4.00    2501.00        511.00   -1796.00   -3161.00   -3225.00
# 25%        74.00    2562.00        684.00       0.00       0.00       0.00
# 50%       136.00    2630.00       5142.00       0.09       0.08       0.08
# 75%       195.00    2775.00       5511.00       8.34       8.46       8.43
# max       276.00    2961.00       5911.00  176405.00  181137.00  185960.00
#
#            Y2017      Y2018
# count   59437.00   59507.00
# mean      140.92     143.76
# std      1671.86    1710.78
# min     -1582.00   -3396.00
# 25%         0.00       0.00
# 50%         0.10       0.07
# 75%         9.00       9.00
# max    190873.00  195875.00

# %%
food_data.groupby('Element').sum()
# Out:
# <ipython-input-107-6be11dff65e9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...

# %%
b=food_data[['Y2017', 'Area']].groupby('Area').sum()
b.sort_values(by='Y2017', ascending=True)
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
food_data.groupby('Item').sum()
# Out:
# <ipython-input-109-668d602dad3c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby('Item').sum()
#                      Area Code  Item Code  Element Code      Y2014      Y2015  \
# Item
# Alcohol, Non-Food        38447     752497       1515090    2403.00    2180.00
# Alcoholic Beverages      75016    1649136       2171381  102410.11   98783.72
# Animal Products          18060     397035         90990   11935.65   11811.73
# Animal fats              85279    1882494       2567303  209460.54  200675.72
# Apples and products      69280    1352989       1920418    9499.23   10559.15
# ...                        ...        ...           ...        ...        ...
# Vegetables, Other        77779    1518715       2275409  155038.96  158104.08
# ...

# %%
b.sort_values(by='Y2017', ascending=True)
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %%
food_data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']
s=pd.DataFrame(lst, columns=col, index=[i for i in range(1,4)])
s
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
array  = ([[94, 89, 63],[93, 92, 48],[92, 94, 56]])

#Its a tuple

# %%
food_data.groupby('Element').sum()
# Out:
# <ipython-input-115-6be11dff65e9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   food_data.groupby('Element').sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...
